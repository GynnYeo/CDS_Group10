# %%
# !pip install pytorch-tabnet -q
# Out:
# Error processing line 1 of /Users/tonieenriquez/anaconda3/lib/python3.11/site-packages/distutils-precedence.pth:
#
#   Traceback (most recent call last):
#     File "<frozen site>", line 186, in addpackage
#     File "<string>", line 1, in <module>
#   ModuleNotFoundError: No module named '_distutils_hack'
#
# Remainder of file ignored
#
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
from __future__ import annotations

import sys
import warnings
from pathlib import Path

import numpy as np
import pandas as pd
import torch
from sklearn.metrics import roc_auc_score
from sklearn.impute import SimpleImputer

warnings.filterwarnings("ignore")

PROJECT_ROOT = Path.cwd().resolve()
while not (PROJECT_ROOT / "src").exists():
    if PROJECT_ROOT.parent == PROJECT_ROOT:
        raise RuntimeError("Could not find repo root containing /src")
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print("PROJECT_ROOT =", PROJECT_ROOT)
print("torch       =", torch.__version__)

from pytorch_tabnet.tab_model import TabNetClassifier

from src.evaluation import evaluate_binary_probabilities
from src.models.feature_sets import (
    BASE_TABULAR_FEATURES,
    GCMT_FEATURES,
    QUALITY_FEATURES,
)
from src.models.input_layer import (
    InputConfig,
    load_modeling_splits,
    prepare_tabular_inputs,
)
from src.utils.paths import METRICS_DIR
# Out:
# PROJECT_ROOT = /Users/tonieenriquez/Desktop/SUTD/SoftwareConstruction/CDS_Group10
# torch       = 2.10.0

# %%
DATASET_NAME = "earthquake_aftershock_v2_gcmt"
MODEL_NAME = "tabnet_best_v1"
TARGETS = ["y_24h", "y_72h"]

SEED = 42
np.random.seed(SEED)
torch.manual_seed(SEED)

# %%
splits = load_modeling_splits(dataset_name=DATASET_NAME)

for split_name, df in splits.items():
    print(
        f"{split_name:5s}  {len(df):>5} rows  |  "
        f"y_24h pos: {df['y_24h'].mean():.3f}  "
        f"y_72h pos: {df['y_72h'].mean():.3f}"
    )
# Out:
# train  23031 rows  |  y_24h pos: 0.443  y_72h pos: 0.504
# val     1744 rows  |  y_24h pos: 0.478  y_72h pos: 0.535
# test    3513 rows  |  y_24h pos: 0.469  y_72h pos: 0.530

# %%
def engineer_features(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()
    has_gcmt = df["has_gcmt"].fillna(False) if "has_gcmt" in df.columns else pd.Series(False, index=df.index)

    # Depth regime
    if "trigger_depth_km" in df.columns:
        df["depth_shallow"] = (df["trigger_depth_km"] < 70).astype(float)
        df["depth_intermediate"] = (df["trigger_depth_km"].between(70, 300)).astype(float)
        df["depth_deep"] = (df["trigger_depth_km"] > 300).astype(float)

    # Magnitude / activity transforms
    if "trigger_magnitude" in df.columns:
        df["log_magnitude"] = np.log10(df["trigger_magnitude"].clip(lower=1e-6))

    if "trigger_magnitude" in df.columns and "trigger_depth_km" in df.columns:
        df["mag_depth_ratio"] = df["trigger_magnitude"] / (df["trigger_depth_km"] + 1)

    if "prior_global_event_count_24h" in df.columns:
        df["log_prior_24h"] = np.log1p(df["prior_global_event_count_24h"])

    if "prior_global_event_count_7d" in df.columns:
        df["log_prior_7d"] = np.log1p(df["prior_global_event_count_7d"])

    if "prior_global_event_count_24h" in df.columns and "prior_global_event_count_7d" in df.columns:
        denom = (df["prior_global_event_count_7d"] / 7.0).replace(0, np.nan)
        df["seismicity_acceleration"] = df["prior_global_event_count_24h"] / denom

    if "trigger_magnitude" in df.columns and "prior_global_event_count_24h" in df.columns:
        df["mag_x_log_prior"] = df["trigger_magnitude"] * np.log1p(df["prior_global_event_count_24h"])

    if "trigger_magnitude" in df.columns and "depth_shallow" in df.columns:
        df["mag_x_shallow"] = df["trigger_magnitude"] * df["depth_shallow"]

    # Time cyclicals
    if "trigger_month" in df.columns:
        df["sin_month"] = np.sin(2 * np.pi * df["trigger_month"] / 12)
        df["cos_month"] = np.cos(2 * np.pi * df["trigger_month"] / 12)

    if "trigger_hour" in df.columns:
        df["sin_hour"] = np.sin(2 * np.pi * df["trigger_hour"] / 24)
        df["cos_hour"] = np.cos(2 * np.pi * df["trigger_hour"] / 24)

    if "trigger_dayofyear" in df.columns:
        df["sin_dayofyear"] = np.sin(2 * np.pi * df["trigger_dayofyear"] / 365)
        df["cos_dayofyear"] = np.cos(2 * np.pi * df["trigger_dayofyear"] / 365)

    # Spatial
    if "trigger_longitude" in df.columns and "trigger_latitude" in df.columns:
        df["ring_of_fire"] = (
            (np.abs(df["trigger_longitude"]) > 130)
            & (df["trigger_latitude"].between(-60, 60))
        ).astype(float)

    # GCMT-enriched features
    if "gcmt_scalar_moment" in df.columns:
        df["log_scalar_moment"] = np.where(
            has_gcmt & df["gcmt_scalar_moment"].notna(),
            np.log10(df["gcmt_scalar_moment"].clip(lower=1e-10)),
            np.nan,
        )

    if "gcmt_moment_exponent" in df.columns:
        df["moment_exponent_centered"] = (df["gcmt_moment_exponent"] - 24.0).where(has_gcmt)

    if "gcmt_scalar_moment" in df.columns and "trigger_magnitude" in df.columns:
        df["gcmt_mw"] = np.where(
            has_gcmt & df["gcmt_scalar_moment"].notna(),
            (2 / 3) * np.log10(df["gcmt_scalar_moment"].clip(lower=1e-10)) - 10.7,
            np.nan,
        )
        df["mw_trigger_diff"] = (df["gcmt_mw"] - df["trigger_magnitude"]).where(has_gcmt)

    if "dip" in df.columns:
        df["sin_dip"] = np.sin(np.radians(df["dip"].where(has_gcmt)))

    if {"gcmt_eig1", "gcmt_eig2", "gcmt_eig3"}.issubset(df.columns):
        e1 = df["gcmt_eig1"].where(has_gcmt)
        e2 = df["gcmt_eig2"].where(has_gcmt)
        e3 = df["gcmt_eig3"].where(has_gcmt)
        denom = (e1.abs() + e3.abs()).replace(0, np.nan)
        df["clvd_fraction"] = (2 * e2.abs() / denom).where(has_gcmt)
        df["eig_ratio"] = (e1.abs() / denom).where(has_gcmt)

    if {"gcmt_eig1_plunge", "gcmt_eig3_plunge"}.issubset(df.columns):
        p1 = df["gcmt_eig1_plunge"].where(has_gcmt)
        p3 = df["gcmt_eig3_plunge"].where(has_gcmt)
        df["sin_eig1_plunge"] = np.sin(np.radians(p1))
        df["cos_eig1_plunge"] = np.cos(np.radians(p1))
        df["sin_eig3_plunge"] = np.sin(np.radians(p3))
        df["cos_eig3_plunge"] = np.cos(np.radians(p3))
        df["tp_plunge_diff"] = (p1 - p3).where(has_gcmt)

    if "gcmt_depth_km" in df.columns and "trigger_depth_km" in df.columns:
        df["centroid_depth_diff"] = (df["gcmt_depth_km"] - df["trigger_depth_km"]).where(has_gcmt)

    if "gcmt_half_duration_sec" in df.columns:
        df["log_half_duration"] = np.log1p(df["gcmt_half_duration_sec"].where(has_gcmt))

    if "gcmt_mag_diff" in df.columns:
        df["mag_diff_abs"] = df["gcmt_mag_diff"].abs().where(has_gcmt)

    if "rake" in df.columns:
        def _rake_regimes(rake: float):
            if pd.isna(rake):
                return np.nan, np.nan, np.nan
            r = rake % 360
            ss_dist = min(abs(r), abs(r - 180), abs(r - 360))
            return float(ss_dist < 45), float(45 <= r <= 135), float(225 <= r <= 315)

        regimes = df["rake"].apply(_rake_regimes)
        df["is_strike_slip"] = regimes.apply(lambda x: x[0]).where(has_gcmt)
        df["is_reverse"] = regimes.apply(lambda x: x[1]).where(has_gcmt)
        df["is_normal"] = regimes.apply(lambda x: x[2]).where(has_gcmt)

    return df

splits_eng = {name: engineer_features(df) for name, df in splits.items()}
print("Feature engineering complete.")
print("Columns after engineering:", splits_eng["train"].shape[1])
# Out:
# Feature engineering complete.
# Columns after engineering: 127

# %%
ENGINEERED_FEATURES = [
    "depth_shallow", "depth_intermediate", "depth_deep",
    "log_magnitude", "mag_depth_ratio",
    "log_prior_24h", "log_prior_7d", "seismicity_acceleration",
    "mag_x_log_prior", "mag_x_shallow",
    "sin_month", "cos_month",
    "sin_hour", "cos_hour",
    "sin_dayofyear", "cos_dayofyear",
    "ring_of_fire",
    "log_scalar_moment", "moment_exponent_centered",
    "gcmt_mw", "mw_trigger_diff",
    "sin_dip",
    "clvd_fraction", "eig_ratio",
    "sin_eig1_plunge", "cos_eig1_plunge",
    "sin_eig3_plunge", "cos_eig3_plunge",
    "tp_plunge_diff",
    "centroid_depth_diff",
    "log_half_duration",
    "mag_diff_abs",
    "is_strike_slip", "is_reverse", "is_normal",
]

_seen = set()
FULL_FEATURE_SET = []

for f in (BASE_TABULAR_FEATURES + QUALITY_FEATURES + GCMT_FEATURES + ENGINEERED_FEATURES):
    if f not in _seen:
        FULL_FEATURE_SET.append(f)
        _seen.add(f)

print("Total features:", len(FULL_FEATURE_SET))

missing_engineered = [c for c in ENGINEERED_FEATURES if c not in splits_eng["train"].columns]
print("Missing engineered features:", missing_engineered)
# Out:
# Total features: 91
# Missing engineered features: []

# %%
prepared = {}

for target in TARGETS:
    config = InputConfig(
        feature_cols=FULL_FEATURE_SET,
        target_col=target,
        missing_strategy="none",
        scale=False,
        allow_missing_optional=True,
        drop_rows_with_missing_target=True,
    )

    inputs = prepare_tabular_inputs(config=config, splits=splits_eng)
    prepared[target] = inputs
    print(f"{target} — X_train: {inputs.X_train.shape}")
# Out:
# y_24h — X_train: (23031, 91)
# y_72h — X_train: (23031, 91)

# %%
def make_tabnet_arrays(inp):
    imputer = SimpleImputer(strategy="median")

    X_train = imputer.fit_transform(inp.X_train).astype(np.float32)
    X_val   = imputer.transform(inp.X_val).astype(np.float32)
    X_test  = imputer.transform(inp.X_test).astype(np.float32)

    y_train = np.asarray(inp.y_train).astype(int)
    y_val   = np.asarray(inp.y_val).astype(int)
    y_test  = np.asarray(inp.y_test).astype(int)

    return X_train, X_val, X_test, y_train, y_val, y_test, imputer

# %%
TABNET_PARAMS = dict(
    n_d=32,
    n_a=32,
    n_steps=4,
    gamma=1.5,
    n_independent=2,
    n_shared=2,
    lambda_sparse=1e-4,
    optimizer_fn=torch.optim.Adam,
    optimizer_params=dict(lr=2e-2, weight_decay=1e-5),
    mask_type="entmax",
    seed=SEED,
    verbose=1,
)

# %%
models = {}
artifacts = {}

for target in TARGETS:
    inp = prepared[target]
    X_train, X_val, X_test, y_train, y_val, y_test, imputer = make_tabnet_arrays(inp)

    clf = TabNetClassifier(**TABNET_PARAMS)

    clf.fit(
        X_train=X_train,
        y_train=y_train,
        eval_set=[(X_val, y_val)],
        eval_name=["val"],
        eval_metric=["logloss"],
        max_epochs=200,
        patience=25,
        batch_size=512,
        virtual_batch_size=128,
        num_workers=0,
        drop_last=False,
    )

    models[target] = clf
    artifacts[target] = {
    "X_train": X_train,
    "X_val": X_val,
    "X_test": X_test,
    "y_train": y_train,
    "y_val": y_val,
    "y_test": y_test,
    "imputer": imputer,
    "trigger_ids": {
        "train": splits_eng["train"]["trigger_event_id"].values,
        "val": splits_eng["val"]["trigger_event_id"].values,
        "test": splits_eng["test"]["trigger_event_id"].values,
    },
}

    val_prob = clf.predict_proba(X_val)[:, 1]
    test_prob = clf.predict_proba(X_test)[:, 1]

    print(
        f"{target} — val AUC: {roc_auc_score(y_val, val_prob):.4f} | "
        f"test AUC: {roc_auc_score(y_test, test_prob):.4f}"
    )
# Out:
# epoch 0  | loss: 0.71018 | val_logloss: 0.93033 |  0:00:02s
# epoch 1  | loss: 0.59892 | val_logloss: 1.28456 |  0:00:06s
# epoch 2  | loss: 0.57913 | val_logloss: 0.70917 |  0:00:14s
# epoch 3  | loss: 0.56612 | val_logloss: 0.60899 |  0:00:17s
# epoch 4  | loss: 0.5548  | val_logloss: 0.62051 |  0:00:21s
# epoch 5  | loss: 0.5527  | val_logloss: 0.59197 |  0:00:25s
# epoch 6  | loss: 0.54338 | val_logloss: 0.55921 |  0:00:28s
# epoch 7  | loss: 0.53972 | val_logloss: 0.56071 |  0:00:33s
# epoch 8  | loss: 0.53185 | val_logloss: 0.57048 |  0:00:36s
# epoch 9  | loss: 0.52345 | val_logloss: 0.55959 |  0:00:41s
# epoch 10 | loss: 0.52271 | val_logloss: 0.55318 |  0:00:45s
# epoch 11 | loss: 0.52008 | val_logloss: 0.57499 |  0:00:48s
# epoch 12 | loss: 0.51549 | val_logloss: 0.56343 |  0:00:52s
# epoch 13 | loss: 0.51387 | val_logloss: 0.54926 |  0:00:55s
# epoch 14 | loss: 0.51119 | val_logloss: 0.54198 |  0:01:00s
# epoch 15 | loss: 0.50877 | val_logloss: 0.5501  |  0:01:04s
# epoch 16 | loss: 0.50534 | val_logloss: 0.54363 |  0:01:08s
# epoch 17 | loss: 0.50097 | val_logloss: 0.56638 |  0:01:12s
# epoch 18 | loss: 0.49814 | val_logloss: 0.5745  |  0:01:16s
# epoch 19 | loss: 0.50643 | val_logloss: 0.57448 |  0:01:20s
# epoch 20 | loss: 0.51505 | val_logloss: 0.57516 |  0:01:23s
# epoch 21 | loss: 0.5071  | val_logloss: 0.55018 |  0:01:27s
# epoch 22 | loss: 0.50072 | val_logloss: 0.5655  |  0:01:32s
# epoch 23 | loss: 0.49151 | val_logloss: 0.55841 |  0:01:38s
# epoch 24 | loss: 0.49234 | val_logloss: 0.58815 |  0:01:42s
# epoch 25 | loss: 0.49138 | val_logloss: 0.571   |  0:01:46s
# epoch 26 | loss: 0.48744 | val_logloss: 0.54837 |  0:01:50s
# epoch 27 | loss: 0.47589 | val_logloss: 0.58466 |  0:01:53s
# epoch 28 | loss: 0.47138 | val_logloss: 0.55667 |  0:01:58s
# epoch 29 | loss: 0.47228 | val_logloss: 0.57811 |  0:02:03s
# epoch 30 | loss: 0.46417 | val_logloss: 0.58126 |  0:02:07s
# epoch 31 | loss: 0.46216 | val_logloss: 0.5848  |  0:02:11s
# epoch 32 | loss: 0.45964 | val_logloss: 0.57657 |  0:02:16s
# epoch 33 | loss: 0.45655 | val_logloss: 0.6006  |  0:02:19s
# epoch 34 | loss: 0.45392 | val_logloss: 0.59826 |  0:02:23s
# epoch 35 | loss: 0.45267 | val_logloss: 0.62576 |  0:02:27s
# epoch 36 | loss: 0.44438 | val_logloss: 0.60166 |  0:02:32s
# epoch 37 | loss: 0.44051 | val_logloss: 0.5956  |  0:02:37s
# epoch 38 | loss: 0.43338 | val_logloss: 0.60897 |  0:03:02s
# epoch 39 | loss: 0.45047 | val_logloss: 0.58515 |  0:03:10s
#
# Early stopping occurred at epoch 39 with best_epoch = 14 and best_val_logloss = 0.54198
# y_24h — val AUC: 0.8032 | test AUC: 0.7864
# epoch 0  | loss: 0.73151 | val_logloss: 0.92036 |  0:00:03s
# epoch 1  | loss: 0.62536 | val_logloss: 0.86294 |  0:00:06s
# epoch 2  | loss: 0.60832 | val_logloss: 0.64137 |  0:00:11s
# epoch 3  | loss: 0.59528 | val_logloss: 0.60889 |  0:00:20s
# epoch 4  | loss: 0.58454 | val_logloss: 0.59643 |  0:00:25s
# epoch 5  | loss: 0.57678 | val_logloss: 0.57537 |  0:00:29s
# epoch 6  | loss: 0.56624 | val_logloss: 0.58038 |  0:00:33s
# epoch 7  | loss: 0.56813 | val_logloss: 0.59536 |  0:00:37s
# epoch 8  | loss: 0.5635  | val_logloss: 0.59282 |  0:00:40s
# epoch 9  | loss: 0.55734 | val_logloss: 0.57514 |  0:00:44s
# epoch 10 | loss: 0.55209 | val_logloss: 0.5723  |  0:00:47s
# epoch 11 | loss: 0.54907 | val_logloss: 0.56866 |  0:00:54s
# epoch 12 | loss: 0.54455 | val_logloss: 0.57738 |  0:00:59s
# epoch 13 | loss: 0.54023 | val_logloss: 0.56078 |  0:01:04s
# epoch 14 | loss: 0.53768 | val_logloss: 0.56762 |  0:01:08s
# epoch 15 | loss: 0.53562 | val_logloss: 0.56177 |  0:01:13s
# epoch 16 | loss: 0.52903 | val_logloss: 0.57122 |  0:01:17s
# epoch 17 | loss: 0.52196 | val_logloss: 0.56291 |  0:01:21s
# epoch 18 | loss: 0.51743 | val_logloss: 0.58606 |  0:01:25s
# epoch 19 | loss: 0.51671 | val_logloss: 0.58549 |  0:01:29s
# epoch 20 | loss: 0.51093 | val_logloss: 0.58366 |  0:01:32s
# epoch 21 | loss: 0.50666 | val_logloss: 0.58225 |  0:01:36s
# epoch 22 | loss: 0.50471 | val_logloss: 0.59161 |  0:01:39s
# epoch 23 | loss: 0.50393 | val_logloss: 0.59083 |  0:01:43s
# epoch 24 | loss: 0.50372 | val_logloss: 0.59821 |  0:01:48s
# epoch 25 | loss: 0.50183 | val_logloss: 0.57805 |  0:01:53s
# epoch 26 | loss: 0.50039 | val_logloss: 0.57892 |  0:01:58s
# epoch 27 | loss: 0.49256 | val_logloss: 0.59214 |  0:02:01s
# epoch 28 | loss: 0.49223 | val_logloss: 0.62436 |  0:02:04s
# epoch 29 | loss: 0.49278 | val_logloss: 0.58918 |  0:02:08s
# epoch 30 | loss: 0.48569 | val_logloss: 0.60244 |  0:02:12s
# epoch 31 | loss: 0.48099 | val_logloss: 0.60904 |  0:02:17s
# epoch 32 | loss: 0.47692 | val_logloss: 0.59874 |  0:02:22s
# epoch 33 | loss: 0.46697 | val_logloss: 0.59057 |  0:02:25s
# epoch 34 | loss: 0.45922 | val_logloss: 0.59693 |  0:02:29s
# epoch 35 | loss: 0.4558  | val_logloss: 0.60714 |  0:02:33s
# epoch 36 | loss: 0.44584 | val_logloss: 0.65312 |  0:02:36s
# epoch 37 | loss: 0.44611 | val_logloss: 0.61109 |  0:02:39s
# epoch 38 | loss: 0.43966 | val_logloss: 0.65024 |  0:02:43s
#
# Early stopping occurred at epoch 38 with best_epoch = 13 and best_val_logloss = 0.56078
# y_72h — val AUC: 0.7827 | test AUC: 0.7694

# %%
summary_rows = []
prediction_rows = []

for target in TARGETS:
    horizon = int(target.split("_")[1].replace("h", ""))
    clf = models[target]
    art = artifacts[target]

    split_pack = [
        ("train", art["X_train"], art["y_train"], art["trigger_ids"]["train"]),
        ("val",   art["X_val"],   art["y_val"],   art["trigger_ids"]["val"]),
        ("test",  art["X_test"],  art["y_test"],  art["trigger_ids"]["test"]),
    ]

    for split_name, X_arr, y_arr, trigger_ids in split_pack:
        y_prob = clf.predict_proba(X_arr)[:, 1]
        metrics = evaluate_binary_probabilities(y_true=y_arr, y_prob=y_prob)

        summary_rows.append({
            "model_name": MODEL_NAME,
            "split": split_name,
            "horizon": horizon,
            **metrics,
        })

        pred_df = pd.DataFrame({
            "trigger_event_id": trigger_ids,
            "split": split_name,
            "horizon": horizon,
            "model_name": MODEL_NAME,
            "y_true": y_arr,
            "y_prob": y_prob,
        })
        prediction_rows.append(pred_df)

metrics_df = pd.DataFrame(summary_rows)
predictions_df = pd.concat(prediction_rows, ignore_index=True)

metrics_df
# Out:
#        model_name  split  horizon  brier_score  log_loss   roc_auc  n_obs  \
# 0  tabnet_best_v1  train       24     0.165480  0.500058  0.832998  23031
# 1  tabnet_best_v1    val       24     0.180915  0.541982  0.803230   1744
# 2  tabnet_best_v1   test       24     0.188006  0.556354  0.786439   3513
# 3  tabnet_best_v1  train       72     0.178544  0.531407  0.810823  23031
# 4  tabnet_best_v1    val       72     0.189686  0.560776  0.782679   1744
# 5  tabnet_best_v1   test       72     0.195497  0.577463  0.769408   3513
#
#    positive_rate
# 0       0.442838
# 1       0.478211
# 2       0.468545
# 3       0.503539
# 4       0.534977
# 5       0.530316
